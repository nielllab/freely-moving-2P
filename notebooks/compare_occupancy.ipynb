# %%
import numpy as np
import matplotlib.pyplot as plt
import fm2p
# Out:
# Loading DLC 2.3.7...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# c:\Users\dmartins\anaconda3\envs\fm1\lib\site-packages\oasis\functions.py:13: UserWarning: Could not find cvxpy. Don't worry, you can still use OASIS, just not the slower interior point methods we compared to in the papers.
#   warn("Could not find cvxpy. Don't worry, you can still use OASIS, " +

# %%
basepath = r'K:\Mini2P\241219_DMM_DMM037_freemoving'
rec_name = '241219_DMM_DMM037_freemoving_01'
session_props = r'K:\Mini2P\241219_DMM_DMM037_freemoving\session_props.json'
pxls2cm = 86.33960307728161
top = fm2p.Topcam(basepath, rec_name, props=session_props, rnum=1)
body_xyl, body_tracking_results = top.track_body()

fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=300)
ax.plot(body_tracking_results['x'] / pxls2cm, body_tracking_results['y'] / pxls2cm, '.', ms=2, color='k')
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
ax.invert_yaxis()
ax.set_title(rec_name)

raydists_above_sps_thresh = fm2p.calc_rays(body_xyl, body_tracking_results)

plt.subplots(1,1, subplot_kw=dict(projection='polar'), dpi=300)
for rd in raydists_above_sps_thresh:
    plt.plot(np.deg2rad(np.arange(0,360))+(np.pi/2), rd, color='k', alpha=0.2)
plt.yticks([])
plt.xticks([])
plt.tight_layout()
# Out:
# 86.33960307728161

# %%
basepath = r'K:\Mini2P\241227_DMM_DMM037_freemoving'
rec_name = '241227_DMM_DMM037_freemoving_01'
session_props = r'K:\Mini2P\241227_DMM_DMM037_freemoving\session_props.json'
pxls2cm = 86.33960307728161
top = fm2p.Topcam(basepath, rec_name, props=session_props, rnum=1)
body_xyl, body_tracking_results = top.track_body()

fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=300)
ax.plot(body_tracking_results['x'] / pxls2cm, body_tracking_results['y'] / pxls2cm, '.', ms=2, color='k')
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
ax.invert_yaxis()
ax.set_title(rec_name)

# %%
basepath = r'K:\Mini2P\241231_DMM_DMM038_freemoving'
rec_name = '241231_DMM_DMM038_freemoving_01'
session_props = r'K:\Mini2P\241231_DMM_DMM038_freemoving\session_props.json'
pxls2cm = 86.33960307728161
top = fm2p.Topcam(basepath, rec_name, props=session_props, rnum=1)
body_xyl, body_tracking_results = top.track_body()

fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=300)
ax.plot(body_tracking_results['x'] / pxls2cm, body_tracking_results['y'] / pxls2cm, '.', ms=2, color='k')
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
ax.invert_yaxis()
ax.set_title(rec_name)

# %%
basepath = r'K:\Mini2P\241231_DMM_DMM038_freemoving'
rec_name = '241231_DMM_DMM038_freemoving_01'
session_props = r'K:\Mini2P\241231_DMM_DMM038_freemoving\session_props.json'
pxls2cm = 86.33960307728161
top = fm2p.Topcam(basepath, rec_name, props=session_props, rnum=1)
body_xyl, body_tracking_results = top.track_body()

fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=300)
ax.plot(body_tracking_results['x'] / pxls2cm, body_tracking_results['y'] / pxls2cm, '.', ms=2, color='k')
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
ax.invert_yaxis()
ax.set_title(rec_name)
